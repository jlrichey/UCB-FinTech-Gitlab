# %% [markdown]
# 1. Create and initialize the K-means model instance for 2 clusters

# %% [markdown]
# Answer: model = KMeans(n_clusters=2) # could include random_state=0 for example if required

# %% [markdown]
# 2. the goal of ___ learning is to Determine patterns or group data, called data clusters.

# %% [markdown]
# Answer: machine

# %% [markdown]
# 3. which library do you need to import to build a model with n_clusters

# %% [markdown]
# Answer: sklearn (or scikit-learn

# %% [markdown]
# ![clusterquiz.svg](data:image/svg+xml;base64,...)
# 4. Using elbow method for the above image, determine the optimal number of clusters.

# %% [markdown]
# Answer: 3

# %% [markdown]
# 5. Using your optimal number of clusters found above, write a code that would initiate Agglomerative Clustering

# %% [markdown]
# Answer:

# %% [markdown]
# 6. How would you create a list to store the values of k(set the range from 1 to 11)

# %% [markdown]
# Answer: k = list(range(1, 11))

# %% [markdown]
# 7. What is PCA and why do we use it?

# %% [markdown]
# Answer: PCA stands for Principal Component Analysis and it is a way of reducing the complexity of the data analysed for efficiency sake.

# %% [markdown]
# 8. Write a code to import the PCA module, instantiate the PCA instance and declare the number of PCA variables as 2

# %% [markdown]
# Answer:
